# %%
import torch
import glob
import os
import cv2
import matplotlib.pyplot as plt
import random

from torchvision import transforms

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_image_path = os.path.join(
    '..',
    'content',
    'drive',
    'MyDrive',
    'ResNetModel',
    'input',
    'Train',
    '*',
    '*.png'
)
all_image_paths = glob.glob(train_image_path, recursive=True)

# %%
print(all_image_paths[:5])
# Out:
# ['../content/drive/MyDrive/ResNetModel/input/Train/OpenEye/5.png', '../content/drive/MyDrive/ResNetModel/input/Train/OpenEye/6.png', '../content/drive/MyDrive/ResNetModel/input/Train/OpenEye/8.png', '../content/drive/MyDrive/ResNetModel/input/Train/OpenEye/9.png', '../content/drive/MyDrive/ResNetModel/input/Train/OpenEye/10.png']

# %%
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(35),
    transforms.RandomAdjustSharpness(sharpness_factor=2, p=0.5),
])

# %%
plt.figure(figsize=(10, 7))
for i, image_path in enumerate(all_image_paths):
    if i == 9:
        break
    image_index = random.randint(0, len(all_image_paths))
    image = cv2.imread(all_image_paths[image_index])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    tranformed_image = train_transform(image)
    plt.subplot(3, 3, i+1)
    plt.imshow(tranformed_image)
    plt.axis('off')
plt.tight_layout()
plt.show()
